# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Import data
df_prods = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
# Import data
df_ords = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Prepared Data\orders_wrangled.csv', index_col = False)

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id   customer_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
df_ords.describe()
# Out:
#            order_id   customer_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
# Create a dataframe
df_test = pd.DataFrame()

# %%
# Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\kasia\AppData\Local\Temp\ipykernel_4368\772068622.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
# Check missing values
df_prods.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %%
df_prods.isnull()
# Out:
#        product_id  product_name  aisle_id  department_id  prices
# 0           False         False     False          False   False
# 1           False         False     False          False   False
# 2           False         False     False          False   False
# 3           False         False     False          False   False
# 4           False         False     False          False   False
# ...           ...           ...       ...            ...     ...
# 49688       False         False     False          False   False
# 49689       False         False     False          False   False
# 49690       False         False     False          False   False
# 49691       False         False     False          False   False
# 49692       False         False     False          False   False
#
# [49693 rows x 5 columns]

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods.dropna(inplace = True)

# %%
df_prods.shape
# Out:
# (49677, 5)

# %%
df_prods.dropna(subset = [‘product_name’], inplace = True)
# Out:
#   Cell In[24], line 1
#     df_prods.dropna(subset = [‘product_name’], inplace = True)
#                               ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
path = r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis'

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'))

# %%
# Import data
df_ords = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Prepared Data\orders_wrangled.csv', index_col = False)

# %%
df_ords.describe()
# Out:
#            order_id   customer_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
df_ords.drop(columns = ['Unnamed: 0'])
# Out:
#          order_id  customer_id eval_set  order_number  orders_day_of_week  \
# 0         2539329            1    prior             1                   2
# 1         2398795            1    prior             2                   3
# 2          473747            1    prior             3                   3
# 3         2254736            1    prior             4                   4
# 4          431534            1    prior             5                   4
# ...           ...          ...      ...           ...                 ...
# 3421078   2266710       206209    prior            10                   5
# 3421079   1854736       206209    prior            11                   4
# 3421080    626363       206209    prior            12                   1
# 3421081   2977660       206209    prior            13                   1
# 3421082    272231       206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %% [markdown]
# # I don't see anything unusual

# %%
# Check for mixed-type data
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0: 
      print (col)

# %%
for col in df_ords.columns.tolist():
    if len(df_ords[col].apply(type).unique())>1:
        print(col+' have mix datatype')
    else:
        print(col+' don\'t have mix datatype')
# Out:
# Unnamed: 0 don't have mix datatype
# order_id don't have mix datatype
# customer_id don't have mix datatype
# eval_set don't have mix datatype
# order_number don't have mix datatype
# orders_day_of_week don't have mix datatype
# order_hour_of_day don't have mix datatype
# days_since_prior_order don't have mix datatype

# %%
# Check for missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# customer_id                    0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# # There are 206209 missing values in the days_since_prior_order column. They are all NaN, it might mean it's a new customer and it was their first order. In order to check it I need to see if there are any repeated user_id in the df with one oder where the value is NaN

# %%
# Adressing the missing values using an appropriate method
df_ords_clean = df_ords
df_ords_clean['new_customer'] = df_ords['days_since_prior_order'].isnull() == True
df_ords_clean
# Out:
#          order_id  customer_id eval_set  order_number  orders_day_of_week  \
# 0         2539329            1    prior             1                   2
# 1         2398795            1    prior             2                   3
# 2          473747            1    prior             3                   3
# 3         2254736            1    prior             4                   4
# 4          431534            1    prior             5                   4
# ...           ...          ...      ...           ...                 ...
# 3421078   2266710       206209    prior            10                   5
# 3421079   1854736       206209    prior            11                   4
# 3421080    626363       206209    prior            12                   1
# 3421081   2977660       206209    prior            13                   1
# 3421082    272231       206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order  new_customer
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer
# 0                     NaN          True
# 1                    15.0         False
# 2                    21.0         False
# 3                    29.0         False
# 4                    28.0         False

# %%
# Check for duplicates
df_dups = df_ords[df_ords.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, new_customer]
# Index: []

# %% [markdown]
# # Looks like there are no duplicates

# %%
path = r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis'

# %%
df_ords.to_csv(os.path.join(path,'02 Data','Prepared Data','ords_checked.csv'))
