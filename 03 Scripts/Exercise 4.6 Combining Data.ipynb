# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Import data
df_ords_prior = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Original Data\orders_products_prior.csv', index_col = False)

# %%
# Import data
df_ords_clean = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_clean
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# Droppping column eval_set from orders.csv
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
#  Renaming the order_dow column
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# # 03. Merge Data

# %%
# Merge df_ords_prior and df_ords using order_id as a key 

df_merged_large = df_ords_prior.merge(df_ords, on = ['order_id'])

# %%
# Adding merge flag
df_merged_large = df_ords_prior.merge(df_ords, on = ['order_id'], indicator = True)

# %%
df_merged_large
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior             3          5                  9
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
path = r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis'

# %%
# Exporting 
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
