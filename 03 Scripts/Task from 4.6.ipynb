# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Import data
df_orders_products_combined = pd.read_pickle(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order _merge
# 0             3          5                  9                     8.0   both
# 1             3          5                  9                     8.0   both
# 2             3          5                  9                     8.0   both
# 3             3          5                  9                     8.0   both
# 4             3          5                  9                     8.0   both

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['eval_set'])

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    order_dow  order_hour_of_day  days_since_prior_order _merge
# 0          5                  9                     8.0   both
# 1          5                  9                     8.0   both
# 2          5                  9                     8.0   both
# 3          5                  9                     8.0   both
# 4          5                  9                     8.0   both

# %%
df_orders_products_combined.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order _merge
# 0                   5                  9                     8.0   both
# 1                   5                  9                     8.0   both
# 2                   5                  9                     8.0   both
# 3                   5                  9                     8.0   both
# 4                   5                  9                     8.0   both

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
# Import data
df_prods = pd.read_csv(r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order _merge
# 0             3          5                  9                     8.0   both
# 1             3          5                  9                     8.0   both
# 2             3          5                  9                     8.0   both
# 3             3          5                  9                     8.0   both
# 4             3          5                  9                     8.0   both

# %%
#Drop _merge column
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # 03. Merge Data

# %%
# Merge df_orders_products_combined and df_prods using product_id as a key 
df_ords_prods_merge = df_orders_products_combined.merge(df_prods, on = ['product_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Merge df_orders_products_combined and df_prods using product_id as a key
# ----> 2 df_ords_prods_merge = df_orders_products_combined.merge(df_prods, on = ['product_id'])
#
# NameError: name 'df_prods' is not defined

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order _merge  \
# 0                   5                  9                     8.0   both
# 1                   5                  9                     8.0   both
# 2                   5                  9                     8.0   both
# 3                   5                  9                     8.0   both
# 4                   5                  9                     8.0   both
#
#    Unnamed: 0           product_name  aisle_id  department_id  prices
# ...

# %%
#Drop _merge column
df_ords_prods_merge = df_ords_prods_merge.drop(columns = ['_merge'])

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   5                  9                     8.0
# 1                   5                  9                     8.0
# 2                   5                  9                     8.0
# 3                   5                  9                     8.0
# 4                   5                  9                     8.0
#
#             product_name  aisle_id  department_id  prices
# ...

# %%
# Adding merge flag
df_ords_prods_merge = df_orders_products_combined.merge(df_prods, on = ['product_id'], indicator = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Adding merge flag
# ----> 2 df_ords_prods_merge = df_orders_products_combined.merge(df_prods, on = ['product_id'], indicator = True)
#
# NameError: name 'df_orders_products_combined' is not defined

# %%
# Drop _merge column
df_orders_products_combined = df_orders_products_combined.drop(['_merge'], axis=1)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   5                  9                     8.0
# 1                   5                  9                     8.0
# 2                   5                  9                     8.0
# 3                   5                  9                     8.0
# 4                   5                  9                     8.0

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 9)

# %%
# Merge the updated dataframes
df_ords_prods_merge = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True)

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  add_to_cart_order  reordered  user_id  \
# 0             19     5.8      1107                  7          0    38259
# 1             19     5.8      5319                  3          1   196224
# 2             19     5.8      7540                  4          1   138499
# 3             19     5.8      9228                  2          0    79603
# 4             19     5.8      9273                 30          0    50005
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0             2                   1                 11
# ...

# %%
#Drop Unnamed: 0 column
df_ords_prods_merge = df_ords_prods_merge.drop(columns = ['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Drop Unnamed: 0 column
# ----> 2 df_ords_prods_merge = df_ords_prods_merge.drop(columns = ['Unnamed: 0'])
#
# NameError: name 'df_ords_prods_merge' is not defined

# %%
df_ords_prods_merge.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_ords_prods_merge.shape
#
# NameError: name 'df_ords_prods_merge' is not defined

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
path = r'C:\Users\kasia\Desktop\Career Foundry\Achievement 4\06-2024 Instacart Basket Analysis'

# %%
# Exportin combined data
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
